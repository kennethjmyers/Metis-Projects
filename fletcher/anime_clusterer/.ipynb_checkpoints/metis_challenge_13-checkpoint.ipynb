# %% [markdown]
# ### What is this?
#
# I used much of my work from Metis challenge 13 as the basis for my project

# %% [markdown]
# # Challenge Set 13 NLP Unsupervised
#
# Topic: NLP
#
# Date: 02/24/2016
#
# Name: Kenneth Myers
#
# Worked with: NA

# %%
import numpy as np
from numpy import zeros
import pandas as pd
import pickle

from random import sample
from random import random
from collections import defaultdict

from sklearn.externals import joblib

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import KMeans, MiniBatchKMeans
from sklearn.metrics import pairwise_distances
from sklearn.metrics.pairwise import cosine_similarity

import nltk
from nltk.tag.perceptron import PerceptronTagger
from nltk.stem.snowball import SnowballStemmer
from nltk.stem import WordNetLemmatizer


import re
import os
import codecs
from sklearn import feature_extraction
import matplotlib.pyplot as plt
import mpld3

# %matplotlib inline

# %% [markdown]
# ## Challenge 1
#
# Cluster sentences with K-means. If you have your own Fletcher text data, get sentences out and cluster them. If not, cluster the tweets you gathered during the last challenge set. For each cluster, print out the sentences, try to see how close the sentences are. Try different K values and try to find a K value that makes the most sense (the sentences look like they do form a meaningful cluster).
#
# How do you deal with retweets (if you're clustering tweets)?

# %% [markdown]
# ### Note
# I will be working with my own dataset.

# %%
with open('tableaucolors.pkl', 'rb') as file:
    tbl_colors = pickle.load(file)

# %%
#this is for speeding up pos_tag() since pos_tag() is very slow due to unpickling each time
tagger = PerceptronTagger()

# %% [markdown]
# #### filter out those with less than 25 words

# %%
full_data = pd.read_csv('full_anime_data_set.csv')
full_data.dropna(subset=['synopsis'], inplace=True)
synops = list(full_data['synopsis'])

short_indices = []
for i, synop in enumerate(synops):
    if len(synop.split()) <= 25:
        short_indices.append(i)
        
synops = [synop for i, synop in enumerate(synops) if i not in short_indices]
full_data = full_data.drop(full_data.index[short_indices])

# %% [markdown]
# ### Preprocessing

# %%
stemmer = SnowballStemmer("english")
lemmatizer = WordNetLemmatizer()

# %%
joblib.dump(stops, 'stop_words.pkl')
# Out:
# ['stop_words.pkl']

# %%
stops = set([
    "episode", "dvd", "special", "short", "movie", "included", "recap", "season", 
    "second", "film", "volume", "bundled", "tv", "aired", "version", "ova", 
    "tv", "animation", "animated", "releases", "based", "novel", "ova", "released",
    "manga", "edition", "featuring", "features", "created", "called",
    "main", "lot", "named", "feature", "anime", "adaptation", "releases",
    "series", "information", "original", "characters", "new", "story",
    "ovum", "character", "produced", "final", "meet", "scenes", "various", "plot",
    "video", "meeting", "people", "release", "end", "japanese", "japan", "young",
    "episodes", "include", "specials", "animate", "base", "game", "later", "contain",
    "set", "volumes", "bundle", "air", "different", "limit", "time", "live", "make",
    "a", "about", "above", "across", "after", "afterwards", "again", "against",
    "all", "almost", "alone", "along", "already", "also", "although", "always",
    "am", "among", "amongst", "amoungst", "amount", "an", "and", "another",
    "any", "anyhow", "anyone", "anything", "anyway", "anywhere", "are",
    "around", "as", "at", "back", "be", "became", "because", "become",
    "becomes", "becoming", "been", "before", "beforehand", "behind", "being",
    "below", "beside", "besides", "between", "beyond", "bill", "both",
    "bottom", "but", "by", "call", "can", "cannot", "cant", "co", "con",
    "could", "couldnt", "cry", "de", "describe", "detail", "do", "done",
    "down", "due", "during", "each", "eg", "eight", "either", "eleven", "else",
    "elsewhere", "empty", "enough", "etc", "even", "ever", "every", "everyone",
    "everything", "everywhere", "except", "few", "fifteen", "fifty", "fill",
    "find", "fire", "first", "five", "for", "former", "formerly", "forty",
    "found", "four", "from", "front", "full", "further", "get", "give", "go",
    "had", "has", "hasnt", "have", "he", "hence", "her", "here", "hereafter",
    "hereby", "herein", "hereupon", "hers", "herself", "him", "himself", "his",
    "how", "however", "hundred", "i", "ie", "if", "in", "inc", "indeed",
    "interest", "into", "is", "it", "its", "itself", "keep", "last", "latter",
    "latterly", "least", "less", "ltd", "made", "many", "may", "me",
    "meanwhile", "might", "mill", "mine", "more", "moreover", "most", "mostly",
    "move", "much", "must", "my", "myself", "name", "namely", "neither",
    "never", "nevertheless", "next", "nine", "no", "nobody", "none", "noone",
    "nor", "not", "nothing", "now", "nowhere", "of", "off", "often", "on",
    "once", "one", "only", "onto", "or", "other", "others", "otherwise", "our",
    "ours", "ourselves", "out", "over", "own", "part", "per", "perhaps",
    "please", "put", "rather", "re", "same", "see", "seem", "seemed",
    "seeming", "seems", "serious", "several", "she", "should", "show", "side",
    "since", "sincere", "six", "sixty", "so", "some", "somehow", "someone",
    "something", "sometime", "sometimes", "somewhere", "still", "such",
    "system", "take", "ten", "than", "that", "the", "their", "them",
    "themselves", "then", "thence", "there", "thereafter", "thereby",
    "therefore", "therein", "thereupon", "these", "they", "thick", "thin",
    "third", "this", "those", "though", "three", "through", "throughout",
    "thru", "thus", "to", "together", "too", "top", "toward", "towards",
    "twelve", "twenty", "two", "un", "under", "until", "up", "upon", "us",
    "very", "via", "was", "we", "well", "were", "what", "whatever", "when",
    "whence", "whenever", "where", "whereafter", "whereas", "whereby",
    "wherein", "whereupon", "wherever", "whether", "which", "while", "whither",
    "who", "whoever", "whole", "whom", "whose", "why", "will", "with",
    "within", "without", "would", "yet", "you", "your", "yours", "yourself",
    "yourselves"])

# %%
def tokenize_and_stem(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word for sent in nltk.sent_tokenize(text.replace("'", '')) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    #stems = [stemmer.stem(t) for t in filtered_tokens]
    stems = [lemmatizer.lemmatize(t, pos='v') for t in filtered_tokens]
    return stems

def tokenize_only(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word.lower() for sent in nltk.sent_tokenize(text.replace("'", '')) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    return filtered_tokens

# %%
def clean_synops(synopses, nouns_only = False):
    cleaned_synopses = []
    for synopsis in synopses:
        cleaned_tokens = tokenize_and_stem(synopsis)
        cleaned_tokens = [word.lower() for word in cleaned_tokens]
        if nouns_only:
            tags = tagger.tag(cleaned_tokens)
            cleaned_tokens = [t[0] for t in tags if t[1] == "NN"]

        cleaned_synopses.append(" ".join(cleaned_tokens))
        
    return cleaned_synopses

# %%
totalvocab_stemmed = []
totalvocab_tokenized = []
for i in synops:
    allwords_stemmed = tokenize_and_stem(i) #for each item in 'synopses', tokenize/stem
    totalvocab_stemmed.extend(allwords_stemmed) #extend the 'totalvocab_stemmed' list
    
    allwords_tokenized = tokenize_only(i)
    totalvocab_tokenized.extend(allwords_tokenized)

# %%
vocab_frame = pd.DataFrame({'words': totalvocab_tokenized}, index = totalvocab_stemmed)
print('there are ' + str(vocab_frame.shape[0]) + ' items in vocab_frame')
# Out:
# there are 535862 items in vocab_frame

# %% [markdown]
# ### Bag of words

# %%
wordbag_vectorizer = CountVectorizer(analyzer = "word",   \
                                     tokenizer = None,    \
                                     preprocessor = None, \
                                     max_df = 0.2, \
                                     min_df = 0.01, \
                                     stop_words = stops,   \
                                     max_features = 5000)

# %%
cleaned_synops = clean_synops(synops)

# %%
bag_of_words = wordbag_vectorizer.fit_transform(cleaned_synops)
bag_of_words = bag_of_words.toarray()

# %%
vocab_dict = wordbag_vectorizer.vocabulary_

    
terms = []
for k,_ in vocab_dict.items():
    terms.append(k)
    
terms = np.sort(np.array(terms))

# %%
num_clusters = 10

km = KMeans(n_clusters=num_clusters)

# %time km.fit(bag_of_words)

clusters = km.labels_.tolist()
# Out:
# CPU times: user 11 s, sys: 189 ms, total: 11.2 s
# Wall time: 7.16 s

# %%
full_data['clusters'] = clusters
full_data.set_index('clusters', inplace=True)
full_data.head()
cluster_names = defaultdict(str)

# %%
print("Top terms per cluster:")
print()
#sort cluster centers by proximity to centroid
order_centroids = km.cluster_centers_.argsort()[:, ::-1] 

for i in range(num_clusters):
    print("Cluster %d words:" % i, end='')
    
    temp_list = []
    for ind in order_centroids[i, :6]: #replace 6 with n words per cluster
        try:
            temp_list.append(terms[ind])
            print(' %s' % vocab_frame.ix[terms[ind].split(' ')].values.tolist()[0][0].encode('utf-8', 'ignore'), end=',')
        except:
            pass
    #the line below is for creating labels for the graph using the first threw words
    #cluster_names[i] = ', '.join(temp_list[:3])
    
    print() #add whitespace
    print() #add whitespace
    
    print("Cluster %d titles:" % i, end='')
    try:
        for title in list(full_data.ix[i]['title'].values)[:30]:
            try:
                print(' %s,' % title, end='')
            except:
                pass
    except AttributeError:
        print(full_data.ix[i]['title'])
    
    print() #add whitespace
    print() #add whitespace
# Out:
# Top terms per cluster:
#
# Cluster 0 words: b'world', b'friends', b'come', b'day', b'man', b'begins',
#
# Cluster 0 titles: Cowboy Bebop: Tengoku no Tobira, Initial D Fourth Stage, Ring ni Kakero 1, Sunabouzu, Yakitate!! Japan, Neon Genesis Evangelion: The End of Evangelion, Berserk, Rurouni Kenshin: Meiji Kenkaku Romantan - Ishinshishi e no Chinkonka, Aa! Megami-sama!, Kidou Tenshi Angelic Layer, Appleseed (Movie), Chrno Crusade, Rozen Maiden: Träumend, Basilisk: Kouga Ninpou Chou, Full Metal Panic! The Second Raid, Mahou Shoujo Lyrical Nanoha, Mobile Suit Gundam: The 08th MS Team - Miller's Report, Mobile Suit Gundam F91, Mobile Suit Gundam Seed Destiny, Mai-HiME, Ou Dorobou Jing, Ou Dorobou Jing in Seventh Heaven, El Hazard 2: The Magnificent World, Full Moon wo Sagashite, Fushigi Yuugi, Saiyuuki Reload, Saiyuuki Reload Gunlock, GetBackers, Hikaru no Go, Hunter x Hunter OVA,
#
# Cluster 1 words: b'love', b'day', b'life', b'girl', b'fallen', b'come',
#
# Cluster 1 titles: School Rumble, Gunslinger Girl, Kareshi Kanojo no Jijou, Kimi ga Nozomu Eien, Love Hina Christmas Special: Silent Eve, Gravitation, Akane Maniax, Memories Off 2nd, Natsu-iro no Sunadokei, Koi Kaze, Canvas: Sepia-iro no Motif, Yume de Aetara (TV), Kizuna, Papa to Kiss in the Dark, Haru wo Daite Ita, School Days ONA, Boku wa Imouto ni Koi wo Suru, Kamisama Kazoku, Kanojo to Kanojo no Neko, Ranma ½ Specials, Mizuiro, Mizuiro (2003), Zetsuai 1989, Bronze: Zetsuai Since 1989, Love Get Chu, Mobile Suit Gundam III: Encounters in Space, Hachimitsu to Clover II, Wata no Kuni Hoshi, Seikimatsu★Darling, Tonagura!,
#
# Cluster 2 words: b'life', b'world', b'man', b'day', b'girl', b'friends',
#
cluster_range = list(range(1,18,1))
for cluster_size in cluster_range:
    temp_list = []
    for _ in range(3):
        temp_km = KMeans(n_clusters=cluster_size)
        temp_km.fit(bag_of_words)
        temp_list.append(temp_km.inertia_)
        
    inertias.append(np.mean(temp_list))

# %%
plt.plot(cluster_range, inertias)
plt.ylabel('total inertia distance')
plt.xlabel('cluster size')
plt.show()

# %% [markdown]
# ## Challenge 3
#
# Let's name the clusters 1
#
# For each cluster, find the sentence closest to the centroid of the cluster.
#
# (You can use [sklearn.metrics.pairwise_distances](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.pairwise_distances.html#sklearn.metrics.pairwise_distances) or [scipy.spatial.distance](http://docs.scipy.org/doc/scipy/reference/spatial.distance.html) [check pdist, cdist, and euclidean distance] to find distances to the centroid). KMeans has a cluster_centers_ attribute.
#
# This sentence (closest to centroid) is now the name of the cluster. For each cluster, print the representative sentence, and print 'N people expressed a similar statement', or something like that relevant to your dataset. (This is very close to what amazon used to do in the reviews section.)
#
# Find the biggest 3 clusters, and print their representative sentences. (This is close to what amazon is doing now in the reviews section, except they choose the sentence from the most helpful review instead of closest to center.)

# %%
for i in range(num_clusters):
    print("Cluster %d words:" % i, end='')
    
    temp_list = []
    for ind in order_centroids[i, :6]: #replace 6 with n words per cluster
        try:
            temp_list.append(terms[ind])
            print(' %s' % vocab_frame.ix[terms[ind].split(' ')].values.tolist()[0][0].encode('utf-8', 'ignore'), end=',')
        except:
            pass
    
    pw_dists = pairwise_distances(bag_of_words, order_centroids[i].reshape(1,-1))
    min_index = np.argmin(pw_dists)
    
    print('\nMost similar synopsis:')
    print(synops[min_index])
    
    print('\nThe number of series in this cluster is: ', len(full_data.ix[i]), '\n\n')
# Out:
# Cluster 0 words: b'world', b'friends', b'come', b'day', b'man', b'begins',
# Most similar synopsis:
# 1. Final Flight of the Osiris The crew of the Osiris discover an army preparing to invade Zion. While one crew member races inside the Matrix to get the message to Zion, the others try desperately to buy her enough time while fighting off an onslaught of Sentinels they can't possibly defeat. 2-3. The Second Renaissance Part 1 and 2 Humans have created the ultimate AI, which is just as smart as they are. But complications arise when these robots and the humans try to exist peacefully, and eventually all-out war breaks out. The humans ultimately lose the war, and become trapped in the Matrix as seen in the live-action films. 4. Kid's Story A young man discovers that his world isn't real, that it's a computer-generated fantasy land created by robots using humans for energy. He escapes with the help of the hacker Neo. Based on the Matrix trilogy. 5. Program Cis and Duo engage in battle in a virtual recreation of Feudal Japan. 6. World Record While running the fastest race in his life, a champion track star breaks free of his computer-generated world for a small period of time. When he goes back to the real world, he has no memories and is placed in a nursing home. Based on the Matrix trilogy. 7. Beyond While looking for her lost pet, a young woman meets up with some kids in Tokyo to play in a "haunted house," which is really a glitch in their computer world. Based on the Matrix trilogy. 8. Detective Story A detective named Ash is called upon by a mysterious organization to hunt down the notorious hacker Trinity. 9. Matriculated A group of scientists capture a robot and place it in a surreal fantasy world. When the robot's friends come in and kill most of the scientists; however, the robot and the last scientist remaining face isolation in the computer-generated world. Based on the Matrix trilogy.
#
# The number of series in this cluster is:  2906
#
#
# Cluster 1 words: b'love', b'day', b'life', b'girl', b'fallen', b'come',
# Most similar synopsis:
#
# The number of series in this cluster is:  538
#
#
# Cluster 3 words: b'schools', b'high', b'student', b'girls', b'day', b'students',
# Most similar synopsis:
# 1. Final Flight of the Osiris The crew of the Osiris discover an army preparing to invade Zion. While one crew member races inside the Matrix to get the message to Zion, the others try desperately to buy her enough time while fighting off an onslaught of Sentinels they can't possibly defeat. 2-3. The Second Renaissance Part 1 and 2 Humans have created the ultimate AI, which is just as smart as they are. But complications arise when these robots and the humans try to exist peacefully, and eventually all-out war breaks out. The humans ultimately lose the war, and become trapped in the Matrix as seen in the live-action films. 4. Kid's Story A young man discovers that his world isn't real, that it's a computer-generated fantasy land created by robots using humans for energy. He escapes with the help of the hacker Neo. Based on the Matrix trilogy. 5. Program Cis and Duo engage in battle in a virtual recreation of Feudal Japan. 6. World Record While running the fastest race in his life, a champion track star breaks free of his computer-generated world for a small period of time. When he goes back to the real world, he has no memories and is placed in a nursing home. Based on the Matrix trilogy. 7. Beyond While looking for her lost pet, a young woman meets up with some kids in Tokyo to play in a "haunted house," which is really a glitch in their computer world. Based on the Matrix trilogy. 8. Detective Story A detective named Ash is called upon by a mysterious organization to hunt down the notorious hacker Trinity. 9. Matriculated A group of scientists capture a robot and place it in a surreal fantasy world. When the robot's friends come in and kill most of the scientists; however, the robot and the last scientist remaining face isolation in the computer-generated world. Based on the Matrix trilogy.
#
# The number of series in this cluster is:  636
#
#
# Cluster 4 words: b'powers', b'fights', b'used', b'known', b'world', b'battles',
# Most similar synopsis:
# GOSHO collection reveals the origin of the smash hit "Detective Conan." "GO" into his world, and we will "SHO" you SEVEN romantic and exciting stories created by GOSHO AOYAMA. WAIT FOR ME A genius inventor, who is still a high school student, has a girlfriend two years older than him. One day, he invents a time machine and attempts to go two years back into the past, to become the same age as her. However, it is she who ultimately uses the machine to travel through time! TEN PLANETS IN THE NIGHT SKY Meet Baby Conan! Yukiko Kudo is looking for her missing husband. The only clue to find him again is to decipher a mysterious message left for her. Their baby, Shinichi Kudo, one who later becomes the famous high school Detective Conan, will at this age already be offering some important hints for her. THE WANDERING RED BATTERFLY A handsome detective, Yusaku Kitakata, receives phone calls from a mysterious woman day after day, with a new case each day. He of course solves them one by one. But the biggest mystery is who is this mysterious woman? PLAY IT AGAIN Thanks to the mystical powers of a Cherry Blossom Tree, a 70-year-old man with a secret sword technique goes back into the past and becomes the same age as his granddaughter. While enjoying his youth for the second time around, he notices that a player is after his granddaughter. SANTA CLAUS IN SUMMER Keisuke, a young man of 17, accidentally activates the Earth Destruction System. The destiny of the Earth now depends on whether he can stop the system within 24 hours. However, suddenly amnesia strikes him and he forgets the pin number to stop the system. The time is running out... DETECTIVE GEORGE'S SPECIAL CASE A girl is fleeing from men in black. She runs into a detective agency and discovers that the detective there is a super-miniature-size, cool dude. He risks his life trying to solve a case for this client. Will they come through in the end? MAKING OF DETECTIVE CONAN Do you know how to make animation? Everybody wants to see the workings of an animation studio. Based on the concept of Detective Conan, the three sub-characters visit the animation studio of Detective Conan. This episode will surely catch the hearts of Detective Conan fans!
#
# The number of series in this cluster is:  265
#
#
# Cluster 7 words: b'schools', b'high', b'girls', b'student', b'girl', b'clubs',
# Most similar synopsis:
# The story takes place in the 21st century. Due to the fact that pollution was becoming a major problem, scientists had developed the use of hydrogen fuel called "HBT" as an alternative to fossil fuels. At this time humans have colonized Mars in search of new place to call home as a result of overpopulation. In the year 2050, a mysterious alien race called the Inbit invaded the Earth. Unable to fight the Inbits, Earth became desolate with only a few pockets of human beings scattered throughout the planet. Many of the refugees escape aboard a few remaining shuttles to seek shelter on the Moon. The Inbit sets up their main base of operations in the Great Lakes area of North America called "Reflex Point". However, the Mars colony, dubbed the Mars Base, did not forget about the plight of Earth. Troops were sent in to fight the Inbits from the Moon, only to fail miserably. The Inbits did not attack Mars, and showed no interest towards the other planets. Surprisingly the Inbit show no hostility towards humans unless they are directly provoked. The Inbit can also sense the presence of HBT, and use of the fuel is limited under their supervision, as HBT is a common component in weapons technology. Overnight the Mars base becomes a gigantic military machine, producing vast amounts of advanced weaponry and trained troops. In 2080, Mars Base sent in the next wave of troops. Although equipped with more technologically advanced equipment and transformable mecha, the attempt to recapture the homeworld was nonetheless a failure. Three years later, Mars Base launched another attack called the Second Earth Recapture Force. One of the troops happened to be Lieutenant Stick Bernard . The mission proved to be unsuccessful as it did three years ago and Stick's fiancée Marlene was killed. After losing her, Stick was forced to crash into Earth, landing in South America. At first, he was sorrowful and depressed at the death of his beloved Marlene. After seeing the holographic recording of his dead betrothed, Stick swore an oath of vengeance. In his quest to reach the Reflex Point on North America, the Inbit 'hive', he meets other characters of the show, forming a group of ragtag freedom fighters on a goal to rid the planet of the Inbits. As the plot unravels, the purpose of the Inbits invasion is revealed. Their sole purpose of coming to the planet was because Earth provides them a suitable place to evolve into more complex beings. However, little did the Inbits know that their endeavor actually threatens to cause the extinction of both humans and Inbits. And thus, it is up to Stick and his group, with the help of human-like Inbits , to convince the supreme ruler of the Inbit, the Refles, to flee from Earth. MOSPEADA stands for Military Operation Soldier Protect Emergency Aviation Dive Auto, one of the transformable motorcycle-armors the series features. The other primary mecha featured in the show is the three-form transformable fighter called the Armo-Fighter AFC-01 Legioss, which is very much similar to the VF-1 Valkyrie variable fighter in The Super Dimension Fortress Macross.
#
# The number of series in this cluster is:  191
#
#
# Cluster 8 words: b'girl', b'day', b'come', b'boy', b'schools', b'little',
# Most similar synopsis:
# The Story takes place in an alternate reality based in the year 1996, where humanity is advanced enough to develop long-range space travel, as well as bases on both the Moon and Mars. However, the Cold War tensions between the United States and the Soviet Union have not ended; rather, they've escalated as both sides build military facilities in space, and the shadow of nuclear conflict looms over humanity, both on and off Earth. Meanwhile, on the Red Planet, an exchange program created by the United Nations to promote peace and understanding is about to begin; the "Cosmic Culture Club", consisting of 16 boys and girls, as well as their instructor Elizabeth, arrives at the UN Mars base, and are being welcomed by the staff. Among the passengers is Anna a 14 year old girl who serves as the narrator for the story. Suddenly, four unidentified humanoid robots classified as Super Powered Tracers are detected, engaged in fierce combat with each other. The UN base is caught in the crossfire and quickly destroyed, killing all but six members of the "Cosmic Culture Club"--Elizabeth, Arthur, Roan, David, Simone and Anna, and leaving them stranded on an inhospitable planet that has suddenly become a battlefield. As the battle ends, the lone SPT standing lands next to the terrified group and opens up revealing a pilot, who simply announces to them, "Earth is at stake". The robots who destroyed the UN base were the creation of the Grados, an alien race, from the Udoria system, who came to the Sol system for the purpose of conquest, seeing an easy victory as the two superpowers raged against each other to exaustion--however, this could also be described as an act of pre-emptive self-defense; the Gradosian supercomputers have determined that humanity will eventually cease its infighting and become powerful enough to spread through the galaxy, posing a destructive threat to even the far off Grados. However, there were two Grados opposed to the plan: human astronaut Ken Asuka, assumed lost during a deep space mission but discovered by the Grados, and his son Null Albarto . As the Grados prepared their invasion fleet, Eiji stows away on board one of the ships and steals their most powerful and advanced weapon, the SPT-LZ-00X Layzner before fleeing, seeking to warn humanity of its impending invasion. It was here where he was attacked. Aside from the Layzner, the surviving humans have now become very important to the Grados; as the only human eyewitnesses to the aliens and their power, the six are the only ones who can convince the warring powers to stand down from destroying each other, and focus on the greater threat.
#
# The number of series in this cluster is:  552
#
#
# Cluster 9 words: b'world', b'mysterious', b'girl', b'fights', b'powers', b'human',
# Most similar synopsis:
# 1. Final Flight of the Osiris The crew of the Osiris discover an army preparing to invade Zion. While one crew member races inside the Matrix to get the message to Zion, the others try desperately to buy her enough time while fighting off an onslaught of Sentinels they can't possibly defeat. 2-3. The Second Renaissance Part 1 and 2 Humans have created the ultimate AI, which is just as smart as they are. But complications arise when these robots and the humans try to exist peacefully, and eventually all-out war breaks out. The humans ultimately lose the war, and become trapped in the Matrix as seen in the live-action films. 4. Kid's Story A young man discovers that his world isn't real, that it's a computer-generated fantasy land created by robots using humans for energy. He escapes with the help of the hacker Neo. Based on the Matrix trilogy. 5. Program Cis and Duo engage in battle in a virtual recreation of Feudal Japan. 6. World Record While running the fastest race in his life, a champion track star breaks free of his computer-generated world for a small period of time. When he goes back to the real world, he has no memories and is placed in a nursing home. Based on the Matrix trilogy. 7. Beyond While looking for her lost pet, a young woman meets up with some kids in Tokyo to play in a "haunted house," which is really a glitch in their computer world. Based on the Matrix trilogy. 8. Detective Story A detective named Ash is called upon by a mysterious organization to hunt down the notorious hacker Trinity. 9. Matriculated A group of scientists capture a robot and place it in a surreal fantasy world. When the robot's friends come in and kill most of the scientists; however, the robot and the last scientist remaining face isolation in the computer-generated world. Based on the Matrix trilogy.
#
# The number of series in this cluster is:  323

# %% [markdown]
# This is very interesting and kind of hilarious. The same series is appearing 6 times because it is actually a collection of short stories and the description covers each story (each story being very different). I may need to remove this one in the final analysis

# %% [markdown]
# ## Challenge 4
#
# Let's name the clusters 2
#
# Calculate the tf-idf of each word in each cluster (think of all sentences of a cluster together as a document). Represent each cluster with the top 1, or top 2 or... to 5 tf-idf words. For each cluster, print the name (keywords) of the cluster, and "N statements" in the cluster (N is the size of the cluster)

# %%
full_data = pd.read_csv('full_anime_data_set.csv')
full_data.dropna(subset=['synopsis'], inplace=True)
synops = list(full_data['synopsis'])

short_indices = []
for i, synop in enumerate(synops):
    if len(synop.split()) <= 25:
        short_indices.append(i)
        
synops = [synop for i, synop in enumerate(synops) if i not in short_indices]
full_data = full_data.drop(full_data.index[short_indices])

# %%
cleaned_synops = clean_synops(synops)

# %%
tfidf_vectorizer = TfidfVectorizer(max_df=0.2, max_features=200000,
                                   min_df=0.01, stop_words=stops,
                                   use_idf=True, tokenizer=tokenize_and_stem, ngram_range=(1,3))

tfidf_matrix = tfidf_vectorizer.fit_transform(cleaned_synops) #fit the vectorizer to synopses

print(tfidf_matrix.shape)

terms = tfidf_vectorizer.get_feature_names()
print(terms)
# Out:
# (6317, 595)
# ['abandon', 'abilities', 'ability', 'able', 'academy', 'accept', 'accident', 'accidentally', 'act', 'action', 'actually', 'advance', 'adventure', 'age', 'ago', 'agree', 'aid', 'aim', 'alien', 'allow', 'ancient', 'angel', 'animals', 'appear', 'appearance', 'approach', 'arm', 'army', 'arrive', 'art', 'ask', 'attack', 'attempt', 'attend', 'awaken', 'away', 'bad', 'band', 'battle', 'bear', 'beat', 'beautiful', 'begin', 'believe', 'best', 'best friend', 'better', 'big', 'bite', 'black', 'blood', 'blue', 'body', 'book', 'boy', 'boys', 'break', 'bring', 'brother', 'brothers', 'build', 'captain', 'capture', 'care', 'carry', 'case', 'cast', 'cat', 'catch', 'cause', 'center', 'century', 'certain', 'challenge', 'chance', 'change', 'chaos', 'chase', 'child', 'childhood', 'childhood friend', 'children', 'choose', 'city', 'claim', 'clan', 'class', 'classmate', 'classmates', 'close', 'club', 'collect', 'college', 'combat', 'come', 'comedy', 'companion', 'company', 'compete', 'complete', 'completely', 'computer', 'conflict', 'conquer', 'continue', 'control', 'country', 'couple', 'course', 'cover', 'create', 'creature', 'creatures', 'crew', 'crush', 'curse', 'cute', 'danger', 'dangerous', 'dark', 'date', 'daughter', 'day', 'days', 'dead', 'deal', 'death', 'decide', 'deep', 'defeat', 'defend', 'demon', 'demons', 'design', 'desire', 'desperate', 'despite', 'destroy', 'destruction', 'detective', 'determine', 'develop', 'die', 'disappear', 'discover', 'doctor', 'doesnt', 'dog', 'dont', 'dr.', 'dragon', 'draw', 'dream', 'drive', 'earth', 'elite', 'empire', 'encounter', 'enemies', 'enemy', 'energy', 'enjoy', 'enter', 'entire', 'era', 'erotic', 'escape', 'events', 'eventually', 'everyday', 'evil', 'excite', 'exist', 'existence', 'expect', 'experience', 'explore', 'eye', 'face', 'fact', 'fail', 'fall', 'fall love', 'family', 'famous', 'fantasy', 'far', 'fate', 'father', 'fear', 'feel', 'fellow', 'female', 'fight', 'figure', 'finally', 'fly', 'focus', 'follow', 'force', 'forest', 'forget', 'form', 'free', 'friend', 'friends', 'friendship', 'fun', 'future', 'gain', 'galaxy', 'gang', 'gather', 'ghost', 'giant', 'girl', 'girlfriend', 'girls', 'goal', 'god', 'good', 'government', 'grant', 'great', 'greatest', 'group', 'grow', 'guy', 'hand', 'happen', 'happy', 'hard', 'head', 'hear', 'heart', 'hell', 'help', 'hero', 'heroes', 'hes', 'hide', 'high', 'high school', 'high school student', 'hire', 'history', 'hit', 'hold', 'home', 'hop', 'hope', 'hot', 'house', 'huge', 'human', 'humanity', 'humans', 'hunt', 'idol', 'incident', 'inside', 'instead', 'introduce', 'invade', 'investigate', 'invite', 'involve', 'island', 'isnt', 'job', 'join', 'journey', 'junior', 'just', 'justice', 'key', 'kid', 'kidnap', 'kill', 'kind', 'king', 'kingdom', 'knight', 'know', 'land', 'large', 'late', 'lead', 'leader', 'learn', 'leave', 'legend', 'legendary', 'let', 'lie', 'life', 'light', 'like', 'line', 'little', 'local', 'long', 'look', 'lose', 'love', 'machine', 'magic', 'magical', 'male', 'man', 'manage', 'mankind', 'marry', 'master', 'match', 'matter', 'mean', 'member', 'members', 'memories', 'memory', 'men', 'middle', 'military', 'mind', 'miss', 'mission', 'money', 'monster', 'monsters', 'moon', 'mother', 'murder', 'music', 'mysterious', 'mystery', 'nature', 'near', 'need', 'newly', 'night', 'ninja', 'normal', 'note', 'notice', 'number', 'nurse', 'object', 'occur', 'offer', 'old', 'older', 'open', 'order', 'ordinary', 'organization', 'owner', 'pair', 'parent', 'partner', 'party', 'pass', 'past', 'path', 'pay', 'peace', 'peaceful', 'perfect', 'perform', 'person', 'pick', 'picture', 'piece', 'pilot', 'pirate', 'place', 'plan', 'planet', 'play', 'point', 'police', 'popular', 'possess', 'power', 'powerful', 'prepare', 'present', 'president', 'pretty', 'prevent', 'previous', 'prince', 'princess', 'private', 'problem', 'problems', 'produce', 'professor', 'program', 'project', 'promise', 'protect', 'prove', 'purpose', 'pursue', 'queen', 'quest', 'quickly', 'quite', 'race', 'raise', 're ...

# %%
dist = 1 - cosine_similarity(tfidf_matrix)

# %% [markdown]
# ##### K means

# %%
inertias = []
cluster_range = list(range(1,18,1))
for cluster_size in cluster_range:
    temp_list = []
    for _ in range(3):
        temp_km = KMeans(n_clusters=cluster_size)
        temp_km.fit(tfidf_matrix)
        temp_list.append(temp_km.inertia_)
        
    inertias.append(np.mean(temp_list))

plt.plot(cluster_range, inertias)
plt.ylabel('total inertia distance')
plt.xlabel('cluster size')
plt.show()

# %% [markdown]
# Meaningless, need to use gap statistics

# %% [markdown]
# '''
# import scipy
# import scipy.cluster.vq
# import scipy.spatial.distance
# dst = scipy.spatial.distance.euclidean
#
# def min_sparse(X):
#     if len(X.data) == 0:
#         return 0
#     m = X.data.min()
#     return m if X.getnnz() == X.size else min(m, 0)
#
# def max_sparse(X):
#     if len(X.data) == 0:
#         return 0
#     m = X.data.max()
#     return m if X.getnnz() == X.size else max(m, 0)
#
# def gap(data, refs=None, nrefs=10, ks=range(1,11)):
#     """
#     Compute the Gap statistic for an nxm dataset in data.
#     Either give a precomputed set of reference distributions in refs as an (n,m,k) scipy array,
#     or state the number k of reference distributions in nrefs for automatic generation with a
#     uniformed distribution within the bounding box of data.
#     Give the list of k-values for which you want to compute the statistic in ks.
#     """
#     shape = data.shape
#     if refs==None:
#         tops = []
#         bots = []
#         for i in range(data.shape[1]):
#             row = data.getcol(i)
#             tops.append(max_sparse(row))
#             bots.append(min_sparse(row))
#
#         tops = np.array(tops)
#         bots = np.array(bots)
#         dists = scipy.matrix(scipy.diag(tops-bots))
#
#
#         rands = scipy.random.random_sample(size=(shape[0],shape[1],20))
#         for i in range(nrefs):
#             rands[:,:,i] = rands[:,:,i]*dists+bots
#     else:
#         rands = refs
#
#     gaps = scipy.zeros((len(ks),))
#     for (i,k) in enumerate(ks):
#         temp_km = KMeans(n_clusters=k)
#         temp_km.fit_transform(data)
#         kmc, kml = temp_km.cluster_centers_, temp_km.labels_
#         disp = temp_km.inertia_
#
#         refdisps = scipy.zeros((rands.shape[2],))
#         for j in range(rands.shape[2]):
#             temp_km_2 = KMeans(n_clusters=k)
#             temp_km_2.fit_transform(rands[:,:,j])
#             refdisps[j] = scipy.log(temp_km_2.inertia_)
#         print(k)
#         print(scipy.mean(refdisps), scipy.log(disp))
#         gaps[i] = scipy.mean(refdisps)-scipy.log(disp)
#     return gaps
# '''

# %%
#gaps = gap(tfidf_matrix, ks=range(1,101,10))

# %% [markdown]
# Gap statistics was overly complicated and needs more time to explore

# %%
num_clusters = 16

km = KMeans(n_clusters=num_clusters)

# %time km.fit(tfidf_matrix)

clusters = km.labels_.tolist()
# Out:
# CPU times: user 11.2 s, sys: 175 ms, total: 11.3 s
# Wall time: 12.6 s

# %%
joblib.dump(km,  'doc_cluster.pkl')
km = joblib.load('doc_cluster.pkl')
clusters = list(km.labels_)

# %%
clusters[:10]
# Out:
# [0, 10, 3, 5, 5, 4, 1, 4, 4, 10]

# %%
full_data['clusters'] = clusters
full_data.set_index('clusters', inplace=True)
full_data.head()
cluster_names = defaultdict(str)

# %%
full_data.head()
# Out:
#                                     title  id  episodes  score  rank  \
# clusters
# 0                            Cowboy Bebop   1        26   8.83    20
# 10        Cowboy Bebop: Tengoku no Tobira   5         1   8.41   145
# 3                                  Trigun   6        26   8.32   191
# 5                      Witch Hunter Robin   7        26   7.38  1790
# 5                  Beet the Vandel Buster   8        52   7.05  2889
#
#           popularity  members  favorites  start_date    end_date  \
# clusters
# 0                 27   266713      17715  1998-04-03  1999-04-24
# 10               257    91771        374  2001-09-01  2001-09-01
# 3                 72   175287       5575  1998-04-01  1998-09-30
# 5                591    50136        409  2002-07-02  2002-12-24
# 5               2337     7620         13  2004-09-30  2005-09-29
#
#                    status   type  \
# clusters
# 0         Finished Airing     TV
# 10        Finished Airing  Movie
# 3         Finished Airing     TV
# 5         Finished Airing     TV
# 5         Finished Airing     TV
#
#                                                    synopsis
# clusters
# 0         In the year 2071, humanity has colonized sever...
# 10        As the Cowboy Bebop crew travels the stars, th...
# 3         Vash the Stampede is a wanted man with a habit...
# 5         Witches are individuals with special powers li...
# 5         It is the dark century and the people are suff...

# %%
print("Top terms per cluster:")
print()
#sort cluster centers by proximity to centroid
order_centroids = km.cluster_centers_.argsort()[:, ::-1] 

for i in range(num_clusters):
    print("Cluster %d words:" % i, end='')
    
    temp_list = []
    for ind in order_centroids[i, :6]: #replace 6 with n words per cluster
        try:
            temp_list.append(terms[ind])
            print(' %s' % vocab_frame.ix[terms[ind].split(' ')].values.tolist()[0][0].encode('utf-8', 'ignore'), end=',')
        except:
            pass
    #the line below is for creating labels for the graph using the first threw words
    cluster_names[i] = ', '.join(temp_list[:3])
    
    print() #add whitespace
    print() #add whitespace
    
    print("Cluster %d titles:" % i, end='')
    try:
        for title in list(full_data.ix[i]['title'].values)[:30]:
            try:
                print(' %s,' % title, end='')
            except:
                pass
    except AttributeError:
        print(full_data.ix[i]['title'])
        
    print() #add whitespace
    print() #add whitespace
# Out:
# Top terms per cluster:
#
# Cluster 0 words: b'earth', b'space', b'planet', b'alien', b'pilots', b'war',
#
# Cluster 0 titles: Cowboy Bebop, Neon Genesis Evangelion, Blue Gender, DearS, Mobile Suit Gundam, Mobile Suit Gundam: The 08th MS Team, Mobile Suit Gundam 0080: War in the Pocket, Mobile Suit Gundam 0083: Stardust Memory, Mobile Suit Zeta Gundam, Mobile Suit Gundam ZZ, Mobile Suit Gundam: Char's Counterattack, Mobile Suit Gundam F91, Mobile Suit Victory Gundam, Mobile Suit Gundam Wing, Mobile Suit Gundam Wing: Endless Waltz, After War Gundam X, Mobile Suit Gundam Seed, Turn A Gundam, Mobile Fighter G Gundam, Uchuu no Stellvia, X/1999, Samurai 7, Vandread: The Second Stage, Xenosaga The Animation, Onegai☆Teacher, Kidou Senkan Nadesico, Gunparade March: Arata Naru Kougunka, Argento Soma, Divergence Eve, Divergence Eve 2: Misaki Chronicles,
#
# Cluster 1 words: b'love', b'fallen', b'fallen', b'girl', b'day', b'feelings',
#
# Cluster 1 titles: Hachimitsu to Clover, Aa! Megami-sama! (TV), Full Moon wo Sagashite, Kareshi Kanojo no Jijou, Kimi ga Nozomu Eien, Love Hina Christmas Special: Silent Eve, Samurai Champloo, Hajime no Ippo: Champion Road, Akane Maniax, Paradise Kiss, Marmalade Boy, Memories Off, Memories Off 2nd, Ai Yori Aoshi: Enishi, Iria: Zeiram The Animation, Marmalade Boy Movie, Steel Angel Kurumi Zero, Natsu-iro no Sunadokei, Iketeru Futari, Gunsmith Cats, Denshin Mamotte Shugogetten, Kashimashi: Girl Meets Girl, Dousou Kai, Kizuna, Papa to Kiss in the Dark, Haru wo Daite Ita, True Love Story, School Days ONA, Boku wa Imouto ni Koi wo Suru, School Rumble Ni Gakki,
#
# Cluster 2 words: b'father', b'mother', b'leaving', b'day', b'dying', b'girl',
#
# Cluster 2 titles: Ring ni Kakero 1, Chuuka Ichiban!, Gate Keepers 21, Hunter x Hunter, Loveless, Initial D Third Stage, Ranma ½, Pia Carrot e Youkoso!!, Jungle wa Itsumo Hare nochi Guu, Happy☆Lesson: Advance, Grappler Baki (TV), Zettai Shounen, Futatsu no Spica, Magical Canan, Fate/stay night, Bannou Bunka Neko-Musume, Capeta, Hanaukyou Maid-tai, InuYasha: Toki wo Koeru Omoi, Okusama wa Joshikousei (TV), Kurau Phantom Memory, Kamui no Ken, Makai Toshi Shinjuku, Tekken, Tenchi Muyou! Ryououki 3rd Season, Grappler Baki: Saidai Tournament-hen, DNA², Ginga Nagareboshi Gin, Mamotte Shugogetten!, Major S1,
#
# Cluster 3 words: b'man', b'life', b'mysterious', b'known', b'woman', b'world',
#
# Cluster 14 titles: D.C.: Da Capo, Soukyuu no Fafner: Dead Aggressor, Hunter x Hunter: Greed Island, Hunter x Hunter: Greed Island Final, Love Hina Haru Special: Kimi Sakura Chiru Nakare!!, Macross Zero, Lodoss-tou Senki, Groove Adventure Rave, Stratos 4 Advance, InuYasha: Guren no Houraijima, One Piece (Movie), One Piece: Nejimaki Jima no Daibouken, One Piece: Chinjuujima no Chopper Oukoku, One Piece: Omatsuri Danshaku to Himitsu no Shima, One Piece: Karakurijou no Mecha Kyohei, One Piece: Taose! Kaizoku Ganzack, Slayers: The Motion Picture, Moekan The Animation, Hanaukyou Maid-tai: La Verite, Ranma ½: Kessen Tougenkyou! Hanayome wo Torimodose!, Sister Princess, Dragon Ball Z Movie 11: Super Senshi Gekiha!! Katsu no wa Ore da, Pokemon: Maboroshi no Pokemon Lugia Bakutan, Pokemon: Mizu no Miyako no Mamorigami Latias to Latios, Neo Ranga, Choujuu Densetsu Gestalt, Lupin III: Dead or Alive, Lupin III: Hemingway Paper no Nazo, Lupin III: Walther P-38, Code Geass: Hangyaku no Lelouch,
#
# Cluster 15 words: b'girls', b'schools', b'academy', b'day', b'girl', b'sex',
#
# Cluster 15 titles: Mai-HiME, Futakoi, Gunslinger Girl, Kita e.: Diamond Dust Drops, Strange Dawn, Love Hina, Maburaho, Pia Carrot e Youkoso!!: Sayaka no Koi Monogatari, Girls Bravo: First Season, Happy☆Lesson, Ojamajo Doremi Sharp, Kore ga Watashi no Goshujinsama, Magic Knight Rayearth, Maria-sama ga Miteru: Haru, Girls Bravo: Second Season, Ichigo Mashimaro, Tenchi Muyou! Ryououki, Sakura Taisen: Le Nouveau Paris, Popotan, Platonic Chain, Mouse, Mahoromatic Summer Special, Green Green Thirteen: Erolutions, Sentimental Journey, Otogi Story Tenshi no Shippo, Yume de Aetara, Oniisama e..., Amaenaide yo!! Katsu!!, Princess Princess, Cosplay Complex,

# %% [markdown]
# ##### Multidimensional scaling/PCA

# %%
import os  # for os.path.basename

import matplotlib.pyplot as plt
import matplotlib as mpl

from sklearn.manifold import MDS

from sklearn.decomposition import RandomizedPCA

# %%
#mds = MDS(n_components=2, dissimilarity="precomputed", n_init=2, max_iter=10, n_jobs=-2, random_state=1)
#pos = mds.fit_transform(dist)  # shape (n_components, n_samples)

r_pca = RandomizedPCA(n_components=2)
pos = r_pca.fit_transform(dist)

xs, ys = pos[:, 0], pos[:, 1]

# %%
titles = list(full_data.title)

# %%
#define custom toolbar location
class TopToolbar(mpld3.plugins.PluginBase):
    """Plugin for moving toolbar to top of figure"""

    JAVASCRIPT = """
    mpld3.register_plugin("toptoolbar", TopToolbar);
    TopToolbar.prototype = Object.create(mpld3.Plugin.prototype);
    TopToolbar.prototype.constructor = TopToolbar;
    function TopToolbar(fig, props){
        mpld3.Plugin.call(this, fig, props);
    };

    TopToolbar.prototype.draw = function(){
      // the toolbar svg doesn't exist
      // yet, so first draw it
      this.fig.toolbar.draw();

      // then change the y position to be
      // at the top of the figure
      this.fig.toolbar.toolbar.attr("x", 600);
      this.fig.toolbar.toolbar.attr("y", 0);

      // then remove the draw function,
      // so that it is not called again
      this.fig.toolbar.draw = function() {}
    }
    """
    def __init__(self):
        self.dict_ = {"type": "toptoolbar"}

# %%
#create data frame that has the result of the MDS plus the cluster numbers and titles
df = pd.DataFrame(dict(x=xs, y=ys, label=clusters, title=titles)) 

#group by cluster
groups = df.groupby('label')

#define custom css to format the font and to remove the axis labeling
css = """
text.mpld3-text, div.mpld3-tooltip {
  font-family:Arial, Helvetica, sans-serif;
}

g.mpld3-xaxis, g.mpld3-yaxis {
display: none; }

svg.mpld3-figure {
margin-left: -200px;}
"""

# Plot 
fig, ax = plt.subplots(figsize=(15,10)) #set plot size
ax.margins(0.03) # Optional, just adds 5% padding to the autoscaling

#iterate through groups to layer the plot
#note that I use the cluster_name and cluster_color dicts with the 'name' lookup to return the appropriate color/label
i=0
for name, group in groups:
    points = ax.plot(group.x, group.y, marker='o', linestyle='', ms=5, 
                     label=cluster_names[name], mec='none', 
                     color=tbl_colors[i]
                    )
    ax.set_aspect('auto')
    labels = [i for i in group.title]
    ax.legend(loc='upper left')
    
    #set tooltip using points, labels and the already defined 'css'
    tooltip = mpld3.plugins.PointHTMLTooltip(points[0], labels,
                                       voffset=10, hoffset=10, css=css)
    #connect tooltip to fig
    mpld3.plugins.connect(fig, tooltip, TopToolbar())    
    
    #set tick marks as blank
    ax.axes.get_xaxis().set_ticks([])
    ax.axes.get_yaxis().set_ticks([])
    
    #set axis as blank
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    i+=1

    
ax.legend(numpoints=1) #show legend with only one dot

mpld3.display() #show the plot

#uncomment the below to export to html
#html = mpld3.fig_to_html(fig)
#print(html)
# Out:
# <style>
#
# text.mpld3-text, div.mpld3-tooltip {
#   font-family:Arial, Helvetica, sans-serif;
# }
#
# g.mpld3-xaxis, g.mpld3-yaxis {
# display: none; }
#
# svg.mpld3-figure {
# margin-left: -200px;}
#
# text.mpld3-text, div.mpld3-tooltip {
#   font-family:Arial, Helvetica, sans-serif;
# }
#
# g.mpld3-xaxis, g.mpld3-yaxis {
# display: none; }
#
# svg.mpld3-figure {
# margin-left: -200px;}
#
# text.mpld3-text, div.mpld3-tooltip {
#   font-family:Arial, Helvetica, sans-serif;
# }
#
# g.mpld3-xaxis, g.mpld3-yaxis {
# display: none; }
#
# svg.mpld3-figure {
# margin-left: -200px;}
#
# text.mpld3-text, div.mpld3-tooltip {
#   font-family:Arial, Helvetica, sans-serif;
# }
#
# g.mpld3-xaxis, g.mpld3-yaxis {
# display: none; }
#
# svg.mpld3-figure {
# margin-left: -200px;}
#
# text.mpld3-text, div.mpld3-tooltip {
#   font-family:Arial, Helvetica, sans-serif;
# }
#
# g.mpld3-xaxis, g.mpld3-yaxis {
# display: none; }
#
# svg.mpld3-figure {
# margin-left: -200px;}
#
# text.mpld3-text, div.mpld3-tooltip {
#   font-family:Arial, Helvetica, sans-serif;
# }
#
# g.mpld3-xaxis, g.mpld3-yaxis {
# display: none; }
#
# svg.mpld3-figure {
# margin-left: -200px;}
#
# text.mpld3-text, div.mpld3-tooltip {
#   font-family:Arial, Helvetica, sans-serif;
# }
#
# g.mpld3-xaxis, g.mpld3-yaxis {
# display: none; }
#
# svg.mpld3-figure {
# margin-left: -200px;}
#
# text.mpld3-text, div.mpld3-tooltip {
#   font-family:Arial, Helvetica, sans-serif;
# }
#
# g.mpld3-xaxis, g.mpld3-yaxis {
# display: none; }
#
# svg.mpld3-figure {
# margin-left: -200px;}
#
# text.mpld3-text, div.mpld3-tooltip {
#   font-family:Arial, Helvetica, sans-serif;
# }
#
# g.mpld3-xaxis, g.mpld3-yaxis {
# display: none; }
#
# svg.mpld3-figure {
# margin-left: -200px;}
#
# text.mpld3-text, div.mpld3-tooltip {
#   font-family:Arial, Helvetica, sans-serif;
# }
#
# g.mpld3-xaxis, g.mpld3-yaxis {
# display: none; }
#
# svg.mpld3-figure {
# margin-left: -200px;}
#
# text.mpld3-text, div.mpld3-tooltip {
#   font-family:Arial, Helvetica, sans-serif;
# }
#
# g.mpld3-xaxis, g.mpld3-yaxis {
# display: none; }
#
# svg.mpld3-figure {
# margin-left: -200px;}
#
# text.mpld3-text, div.mpld3-tooltip {
#   font-family:Arial, Helvetica, sans-serif;
# }
#
# g.mpld3-xaxis, g.mpld3-yaxis {
# display: none; }
#
# svg.mpld3-figure {
# margin-left: -200px;}
#
# text.mpld3-text, div.mpld3-tooltip {
#   font-family:Arial, Helvetica, sans-serif;
# }
#
# g.mpld3-xaxis, g.mpld3-yaxis {
# display: none; }
#
# svg.mpld3-figure {
# margin-left: -200px;}
#
# text.mpld3-text, div.mpld3-tooltip {
#   font-family:Arial, Helvetica, sans-serif;
# }
#
# g.mpld3-xaxis, g.mpld3-yaxis {
# display: none; }
#
# svg.mpld3-figure {
# margin-left: -200px;}
#
# text.mpld3-text, div.mpld3-tooltip {
#   font-family:Arial, Helvetica, sans-serif;
# }
#
# g.mpld3-xaxis, g.mpld3-yaxis {
# display: none; }
#
# svg.mpld3-figure {
# margin-left: -200px;}
#
# text.mpld3-text, div.mpld3-tooltip {
#   font-family:Arial, Helvetica, sans-serif;
# }
#
# g.mpld3-xaxis, g.mpld3-yaxis {
# display: none; }
#
# svg.mpld3-figure {
# margin-left: -200px;}
#
# </style>
#
# <div id="fig_el1756147291527922976490716"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#     mpld3.register_plugin("htmltooltip", HtmlTooltipPlugin);
#     HtmlTooltipPlugin.prototype = Object.create(mpld3.Plugin.prototype);
#     HtmlTooltipPlugin.prototype.constructor = HtmlTooltipPlugin;
#     HtmlTooltipPlugin.prototype.requiredProps = ["id"];
#     HtmlTooltipPlugin.prototype.defaultProps = {labels:null, hoffset:0, voffset:10};
#     function HtmlTooltipPlugin(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     HtmlTooltipPlugin.prototype.draw = function(){
#        var obj = mpld3.get_element(this.props.id);
#        var labels = this.props.labels;
#        var tooltip = d3.select("body").append("div")
#                     .attr("class", "mpld3-tooltip")
#                     .style("position", "absolute")
#                     .style("z-index", "10")
#                     .style("visibility", "hidden");
#
#        obj.elements()
#            .on("mouseover", function(d, i){
#                               tooltip.html(labels[i])
#                                      .style("visibility", "visible");})
#            .on("mousemove", function(d, i){
#                     tooltip
#                       .style("top", d3.event.pageY + this.props.voffset + "px")
#                       .style("left",d3.event.pageX + this.props.hoffset + "px");
#                  }.bind(this))
#            .on("mouseout",  function(d, i){
#                            tooltip.style("visibility", "hidden");});
#     };
#
#     mpld3.register_plugin("toptoolbar", TopToolbar);
#     TopToolbar.prototype = Object.create(mpld3.Plugin.prototype);
#     TopToolbar.prototype.constructor = TopToolbar;
#     function TopToolbar(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     TopToolbar.prototype.draw = function(){
#       // the toolbar svg doesn't exist
#       // yet, so first draw it
#       this.fig.toolbar.draw();
#
#       // then change the y position to be
#       // at the top of the figure
#       this.fig.toolbar.toolbar.attr("x", 600);
#       this.fig.toolbar.toolbar.attr("y", 0);
#
#       // then remove the draw function,
#       // so that it is not called again
#       this.fig.toolbar.draw = function() {}
#     }
#
#     mpld3.register_plugin("htmltooltip", HtmlTooltipPlugin);
#     HtmlTooltipPlugin.prototype = Object.create(mpld3.Plugin.prototype);
#     HtmlTooltipPlugin.prototype.constructor = HtmlTooltipPlugin;
#     HtmlTooltipPlugin.prototype.requiredProps = ["id"];
#     HtmlTooltipPlugin.prototype.defaultProps = {labels:null, hoffset:0, voffset:10};
#     function HtmlTooltipPlugin(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     HtmlTooltipPlugin.prototype.draw = function(){
#        var obj = mpld3.get_element(this.props.id);
#        var labels = this.props.labels;
#        var tooltip = d3.select("body").append("div")
#                     .attr("class", "mpld3-tooltip")
#                     .style("position", "absolute")
#                     .style("z-index", "10")
#                     .style("visibility", "hidden");
#
#        obj.elements()
#            .on("mouseover", function(d, i){
#                               tooltip.html(labels[i])
#                                      .style("visibility", "visible");})
#            .on("mousemove", function(d, i){
#                     tooltip
#                       .style("top", d3.event.pageY + this.props.voffset + "px")
#                       .style("left",d3.event.pageX + this.props.hoffset + "px");
#                  }.bind(this))
#            .on("mouseout",  function(d, i){
#                            tooltip.style("visibility", "hidden");});
#     };
#
#     mpld3.register_plugin("toptoolbar", TopToolbar);
#     TopToolbar.prototype = Object.create(mpld3.Plugin.prototype);
#     TopToolbar.prototype.constructor = TopToolbar;
#     function TopToolbar(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     TopToolbar.prototype.draw = function(){
#       // the toolbar svg doesn't exist
#       // yet, so first draw it
#       this.fig.toolbar.draw();
#
#       // then change the y position to be
#       // at the top of the figure
#       this.fig.toolbar.toolbar.attr("x", 600);
#       this.fig.toolbar.toolbar.attr("y", 0);
#
#       // then remove the draw function,
#       // so that it is not called again
#       this.fig.toolbar.draw = function() {}
#     }
#
#     mpld3.register_plugin("htmltooltip", HtmlTooltipPlugin);
#     HtmlTooltipPlugin.prototype = Object.create(mpld3.Plugin.prototype);
#     HtmlTooltipPlugin.prototype.constructor = HtmlTooltipPlugin;
#     HtmlTooltipPlugin.prototype.requiredProps = ["id"];
#     HtmlTooltipPlugin.prototype.defaultProps = {labels:null, hoffset:0, voffset:10};
#     function HtmlTooltipPlugin(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     Html

# %% [markdown]
# ## Challenge 5
#
# ### Let's name the clusters 3
#
# Same as the previous challenge, but this time, calculate tf-idf only for nouns (NN tag) and build keyword(s) with nouns. (This is close to what amazon switched to last year, before settling into the current design). (They would show five nouns, you would click on one and it would show sentences - linked to the reviews- that were related to that noun.)

# %%
full_data = pd.read_csv('full_anime_data_set.csv')
full_data.dropna(subset=['synopsis'], inplace=True)
synops = list(full_data['synopsis'])

short_indices = []
for i, synop in enumerate(synops):
    if len(synop.split()) <= 25:
        short_indices.append(i)
        
synops = [synop for i, synop in enumerate(synops) if i not in short_indices]
full_data = full_data.drop(full_data.index[short_indices])

# %time cleaned_synops = clean_synops(synops, nouns_only=True)
# Out:
# CPU times: user 1min 2s, sys: 914 ms, total: 1min 3s
# Wall time: 1min 5s

# %%
tfidf_vectorizer = TfidfVectorizer(max_df=0.15, max_features=200000,
                                   min_df=0.01, stop_words=stops,
                                   use_idf=True, tokenizer=tokenize_and_stem, ngram_range=(1,3))

tfidf_matrix = tfidf_vectorizer.fit_transform(cleaned_synops) #fit the vectorizer to synopses

print(tfidf_matrix.shape)
# Out:
# (6317, 278)

# %%
terms = tfidf_vectorizer.get_feature_names()
print(terms)
# Out:
# ['ability', 'academy', 'accident', 'act', 'action', 'adventure', 'age', 'alien', 'appear', 'appearance', 'arm', 'army', 'art', 'attack', 'attempt', 'band', 'battle', 'begin', 'blood', 'body', 'book', 'boy', 'break', 'brother', 'build', 'captain', 'capture', 'care', 'case', 'cat', 'cause', 'center', 'century', 'challenge', 'chance', 'change', 'chaos', 'child', 'childhood', 'childhood friend', 'city', 'clan', 'class', 'classmate', 'club', 'college', 'come', 'comedy', 'companion', 'company', 'computer', 'conflict', 'control', 'country', 'couple', 'course', 'create', 'creature', 'crew', 'crush', 'danger', 'dark', 'date', 'daughter', 'day', 'deal', 'death', 'decide', 'defeat', 'demon', 'desire', 'destruction', 'die', 'discover', 'doctor', 'dog', 'dr.', 'dragon', 'dream', 'earth', 'empire', 'encounter', 'enemy', 'energy', 'era', 'escape', 'evil', 'experience', 'eye', 'face', 'fact', 'fall', 'family', 'fate', 'father', 'fear', 'feel', 'fight', 'focus', 'force', 'forest', 'form', 'friend', 'friendship', 'future', 'galaxy', 'gang', 'ghost', 'girlfriend', 'goal', 'god', 'government', 'group', 'guy', 'hand', 'head', 'heart', 'hell', 'help', 'hero', 'hide', 'history', 'home', 'hop', 'hope', 'house', 'humanity', 'idol', 'incident', 'island', 'job', 'join', 'journey', 'justice', 'kid', 'kind', 'king', 'kingdom', 'land', 'lead', 'leader', 'learn', 'life', 'light', 'line', 'look', 'love', 'machine', 'magic', 'man', 'manage', 'mankind', 'master', 'matter', 'mean', 'member', 'memory', 'middle', 'mind', 'mission', 'money', 'monster', 'moon', 'mother', 'murder', 'music', 'mystery', 'nature', 'need', 'night', 'number', 'order', 'organization', 'owner', 'pair', 'parent', 'partner', 'party', 'pass', 'past', 'path', 'peace', 'person', 'picture', 'pilot', 'place', 'plan', 'planet', 'play', 'point', 'police', 'power', 'president', 'prince', 'princess', 'problem', 'professor', 'program', 'project', 'promise', 'purpose', 'quest', 'race', 'reality', 'reason', 'relationship', 'rescue', 'rest', 'result', 'return', 'revenge', 'robot', 'room', 'rule', 'run', 'school girl', 'school student', 'scientist', 'sea', 'search', 'secret', 'sex', 'shadow', 'share', 'ship', 'shop', 'sister', 'situation', 'sky', 'society', 'son', 'song', 'source', 'space', 'spirit', 'star', 'start', 'strength', 'struggle', 'student', 'study', 'style', 'suit', 'summer', 'surprise', 'sword', 'tale', 'task', 'teacher', 'team', 'technology', 'test', 'thing', 'threat', 'title', 'tokyo', 'town', 'train', 'transfer', 'travel', 'treasure', 'trip', 'trouble', 'truth', 'try', 'turn', 'universe', 'use', 'village', 'war', 'water', 'way', 'weapon', 'witch', 'woman', 'word', 'work', 'year']

# %% [markdown]
# ##### K-means

# %%
inertias = []
cluster_range = list(range(1,18,1))
for cluster_size in cluster_range:
    temp_list = []
    for _ in range(3):
        temp_km = KMeans(n_clusters=cluster_size)
        temp_km.fit(tfidf_matrix)
        temp_list.append(temp_km.inertia_)
        
    inertias.append(np.mean(temp_list))

plt.plot(cluster_range, inertias)
plt.ylabel('total inertia distance')
plt.xlabel('cluster size')
plt.show()

# %%
num_clusters = 13
km = KMeans(n_clusters=num_clusters)
# %time km.fit(tfidf_matrix)
clusters = km.labels_.tolist()
# Out:
# CPU times: user 6.2 s, sys: 79.4 ms, total: 6.28 s
# Wall time: 6.51 s

# %%
full_data['clusters'] = clusters
full_data.set_index('clusters', inplace=True)
full_data.head()
cluster_names = defaultdict(str)

# %%
print("Top terms per cluster:")
print()
#sort cluster centers by proximity to centroid
order_centroids = km.cluster_centers_.argsort()[:, ::-1] 

for i in range(num_clusters):
    print("Cluster %d words:" % i, end='')
    
    temp_list = []
    for ind in order_centroids[i, :6]: #replace 6 with n words per cluster
        try:
            temp_list.append(terms[ind])
            print(' %s' % vocab_frame.ix[terms[ind].split(' ')].values.tolist()[0][0].encode('utf-8', 'ignore'), end=',')
        except:
            pass
    #the line below is for creating labels for the graph using the first threw words
    cluster_names[i] = ', '.join(temp_list[:3])
    
    print() #add whitespace
    print() #add whitespace
    
    print("Cluster %d titles:" % i, end='')
    try:
        for title in list(full_data.ix[i]['title'].values)[:30]:
            try:
                print(' %s,' % title, end='')
            except:
                pass
    except AttributeError:
        print(full_data.ix[i]['title'])
        
    print() #add whitespace
    print() #add whitespace
# Out:
# Top terms per cluster:
#
# Cluster 0 words: b'man', b'woman', b'life', b'day', b'way', b'place',
#
# Cluster 0 titles: Trigun, Sunabouzu, Tenshi na Konamaiki, Lodoss-tou Senki: Eiyuu Kishi Den, Mezzo Forte, 3x3 Eyes, eX-Driver the Movie, Gun x Sword, Fullmetal Alchemist: The Conqueror of Shamballa, I My Me! Strawberry Eggs, Kakyuusei 2: Hitomi no Naka no Shoujo-tachi, Cossette no Shouzou, Metropolis, Tetsuwan Birdy, Musekinin Kanchou Tylor, Okusama wa Mahou Shoujo, Juubee Ninpuuchou, Tenshi no Shippo Chu!, Enzai, Sensitive Pornograph, Boku no Sexual Harassment, Tactical Roar, Choujuushin Gravion, .hack//Roots, Tenshi no Tamago, Hokuto no Ken, Usagi-chan de Cue!!, Tokyo Babylon, Mobile Police Patlabor: The Movie, Pokemon: Mizu no Miyako no Mamorigami Latias to Latios,
#
# Cluster 1 words: b'love', b'day', b'feelings', b'friend', b'life', b'teacher',
#
# Cluster 1 titles: School Rumble, Aa! Megami-sama! (TV), Boys Be..., Gunslinger Girl, Kareshi Kanojo no Jijou, Kimi ga Nozomu Eien, Love Hina Christmas Special: Silent Eve, Video Girl Ai, Samurai Champloo, Hajime no Ippo: Champion Road, Akane Maniax, Peach Girl, Marmalade Boy, Memories Off 2nd, Ai Yori Aoshi: Enishi, Gravitation: Lyrics of Love, Marmalade Boy Movie, Steel Angel Kurumi Zero, Natsu-iro no Sunadokei, Iketeru Futari, Denshin Mamotte Shugogetten, Kashimashi: Girl Meets Girl, Kujibiki Unbalance, Sentimental Journey, Dousou Kai, Kizuna, Papa to Kiss in the Dark, Haru wo Daite Ita, School Days ONA, xxxHOLiC Movie: Manatsu no Yoru no Yume,
#
# Cluster 2 words: b'earth', b'war', b'space', b'planet', b'battles', b'alien',
#
# Cluster 2 titles: Cowboy Bebop, Cowboy Bebop: Tengoku no Tobira, Trinity Blood, Appleseed (Movie), Blue Gender, DearS, Basilisk: Kouga Ninpou Chou, Mahou Shoujo Lyrical Nanoha, Mobile Suit Gundam, Mobile Suit Gundam 0080: War in the Pocket, Mobile Suit Gundam 0083: Stardust Memory, Mobile Suit Zeta Gundam, Mobile Suit Gundam ZZ, Mobile Suit Gundam: Char's Counterattack, Mobile Suit Victory Gundam, Mobile Suit Gundam Wing, Mobile Suit Gundam Wing: Endless Waltz, After War Gundam X, Mobile Suit Gundam Seed, Mobile Suit Gundam Seed Destiny, Turn A Gundam, Mobile Fighter G Gundam, Uchuu no Stellvia, Gensoumaden Saiyuuki, X/1999, X, Samurai 7, Vandread: The Second Stage, Xenosaga The Animation, Macross Zero,
#
# Cluster 3 words: b'life', b'day', b'city', b'change', b'order', b'friend',
#
# Cluster 10 titles: Ring ni Kakero 1, Chuuka Ichiban!, Futakoi, Hunter x Hunter, RahXephon, Initial D First Stage, Initial D Third Stage, Ranma ½, Pia Carrot e Youkoso!!, Groove Adventure Rave, Jungle wa Itsumo Hare nochi Guu, Happy☆Lesson (TV), Happy☆Lesson: Advance, Grappler Baki (TV), Zettai Shounen, Happy World!, Tsukuyomi: Moon Phase, Futatsu no Spica, Magical Canan, Fate/stay night, Bannou Bunka Neko-Musume, Capeta, Hanaukyou Maid-tai, InuYasha: Toki wo Koeru Omoi, Okusama wa Joshikousei (TV), Kurau Phantom Memory, Kamui no Ken, Tekken, Grappler Baki: Saidai Tournament-hen, Mamotte Shugogetten!,
#
# Cluster 11 words: b'day', b'place', b'way', b'boy', b'city', b'group',
#
# Cluster 11 titles: Naruto, Zipang, Neon Genesis Evangelion, Neon Genesis Evangelion: The End of Evangelion, Rurouni Kenshin: Meiji Kenkaku Romantan - Tsuiokuhen, .hack//Sign, Kidou Tenshi Angelic Layer, Arc the Lad, Avenger, Chrno Crusade, Full Metal Panic? Fumoffu, Full Metal Panic! The Second Raid, Mobile Suit Gundam F91, Last Exile, Mai-HiME, Mai-Otome, Air, Ou Dorobou Jing, Corrector Yui, Chou Henshin Cosprayers, Sakigake!! Cromartie Koukou, El Hazard: The Wanderers, El Hazard: The Magnificent World, El Hazard 2: The Magnificent World, Final Approach, Fullmetal Alchemist, Fushigi Yuugi, Gate Keepers 21, Saiyuuki Reload, Saiyuuki Reload Gunlock,
#
# Cluster 12 words: b'adventures', b'boy', b'friend', b'life', b'way', b'book',
#
# Cluster 12 titles: Beet the Vandel Buster, One Piece, Gakuen Alice, Hunter x Hunter: Greed Island Final, Pita Ten, Tokyo Underground, Cardcaptor Sakura, Dan Doh!!, Aa! Megami-sama!: Chichaitte Koto wa Benri da ne, Xiao Qian, Bannou Bunka Neko-Musume (1998), Howl no Ugoku Shiro, One Piece: Dead End no Bouken, To Heart 2, Kino no Tabi: The Beautiful World, Doraemon, Tottoko Hamtarou, Majo no Takkyuubin, Tenkuu no Shiro Laputa, Tonari no Totoro, Battle Programmer Shirase, Mimi wo Sumaseba, PopoloCrois, Mahou no Stage Fancy Lala, Kazemakase Tsukikage Ran, Tenchi Muyou!, Bishoujo Senshi Sailor Moon R, Zoids, Detective Conan Movie 01: The Timed Skyscraper, Colorful,

# %% [markdown]
# ## Challenge 6
#
# Cluster the same data with [MiniBatchKMeans](http://scikit-learn.org/stable/modules/generated/sklearn.cluster.MiniBatchKMeans.html). MiniBatchKMeans is a fast way to apply K-means to large data without much loss -- The results are very similar. Instead of using EVERY single point to find the new place of the centroid, MiniBatch just randomly samples a small number (like 100) in the cluster to calculate the new center. Since this is usually very close to the actual center, the algorithm gets there much faster. Try it and compare the results. ([Example on two-feature data](http://scikit-learn.org/stable/auto_examples/cluster/plot_mini_batch_kmeans.html))

# %%
full_data = pd.read_csv('full_anime_data_set.csv')
full_data.dropna(subset=['synopsis'], inplace=True)
synops = list(full_data['synopsis'])

short_indices = []
for i, synop in enumerate(synops):
    if len(synop.split()) <= 25:
        short_indices.append(i)
        
synops = [synop for i, synop in enumerate(synops) if i not in short_indices]
full_data = full_data.drop(full_data.index[short_indices])

# %time cleaned_synops = clean_synops(synops, nouns_only=True)
# Out:
# CPU times: user 1min, sys: 843 ms, total: 1min 1s
# Wall time: 1min 2s

# %%
tfidf_vectorizer = TfidfVectorizer(max_df=0.15, max_features=200000,
                                   min_df=0.01, stop_words=stops,
                                   use_idf=True, tokenizer=tokenize_and_stem, ngram_range=(1,3))

tfidf_matrix = tfidf_vectorizer.fit_transform(cleaned_synops) #fit the vectorizer to synopses

print(tfidf_matrix.shape)

terms = tfidf_vectorizer.get_feature_names()
print(terms)
# Out:
# (6317, 278)
# ['ability', 'academy', 'accident', 'act', 'action', 'adventure', 'age', 'alien', 'appear', 'appearance', 'arm', 'army', 'art', 'attack', 'attempt', 'band', 'battle', 'begin', 'blood', 'body', 'book', 'boy', 'break', 'brother', 'build', 'captain', 'capture', 'care', 'case', 'cat', 'cause', 'center', 'century', 'challenge', 'chance', 'change', 'chaos', 'child', 'childhood', 'childhood friend', 'city', 'clan', 'class', 'classmate', 'club', 'college', 'come', 'comedy', 'companion', 'company', 'computer', 'conflict', 'control', 'country', 'couple', 'course', 'create', 'creature', 'crew', 'crush', 'danger', 'dark', 'date', 'daughter', 'day', 'deal', 'death', 'decide', 'defeat', 'demon', 'desire', 'destruction', 'die', 'discover', 'doctor', 'dog', 'dr.', 'dragon', 'dream', 'earth', 'empire', 'encounter', 'enemy', 'energy', 'era', 'escape', 'evil', 'experience', 'eye', 'face', 'fact', 'fall', 'family', 'fate', 'father', 'fear', 'feel', 'fight', 'focus', 'force', 'forest', 'form', 'friend', 'friendship', 'future', 'galaxy', 'gang', 'ghost', 'girlfriend', 'goal', 'god', 'government', 'group', 'guy', 'hand', 'head', 'heart', 'hell', 'help', 'hero', 'hide', 'history', 'home', 'hop', 'hope', 'house', 'humanity', 'idol', 'incident', 'island', 'job', 'join', 'journey', 'justice', 'kid', 'kind', 'king', 'kingdom', 'land', 'lead', 'leader', 'learn', 'life', 'light', 'line', 'look', 'love', 'machine', 'magic', 'man', 'manage', 'mankind', 'master', 'matter', 'mean', 'member', 'memory', 'middle', 'mind', 'mission', 'money', 'monster', 'moon', 'mother', 'murder', 'music', 'mystery', 'nature', 'need', 'night', 'number', 'order', 'organization', 'owner', 'pair', 'parent', 'partner', 'party', 'pass', 'past', 'path', 'peace', 'person', 'picture', 'pilot', 'place', 'plan', 'planet', 'play', 'point', 'police', 'power', 'president', 'prince', 'princess', 'problem', 'professor', 'program', 'project', 'promise', 'purpose', 'quest', 'race', 'reality', 'reason', 'relationship', 'rescue', 'rest', 'result', 'return', 'revenge', 'robot', 'room', 'rule', 'run', 'school girl', 'school student', 'scientist', 'sea', 'search', 'secret', 'sex', 'shadow', 'share', 'ship', 'shop', 'sister', 'situation', 'sky', 'society', 'son', 'song', 'source', 'space', 'spirit', 'star', 'start', 'strength', 'struggle', 'student', 'study', 'style', 'suit', 'summer', 'surprise', 'sword', 'tale', 'task', 'teacher', 'team', 'technology', 'test', 'thing', 'threat', 'title', 'tokyo', 'town', 'train', 'transfer', 'travel', 'treasure', 'trip', 'trouble', 'truth', 'try', 'turn', 'universe', 'use', 'village', 'war', 'water', 'way', 'weapon', 'witch', 'woman', 'word', 'work', 'year']

# %%
num_clusters = 13
mbk = MiniBatchKMeans(n_clusters=num_clusters)
# %time mbk.fit(tfidf_matrix)
clusters = mbk.labels_.tolist()
# Out:
# CPU times: user 152 ms, sys: 7.84 ms, total: 160 ms
# Wall time: 170 ms

# %%
full_data['clusters'] = clusters
full_data.set_index('clusters', inplace=True)
full_data.head()
cluster_names = defaultdict(str)

# %%
print("Top terms per cluster:")
print()
#sort cluster centers by proximity to centroid
order_centroids = mbk.cluster_centers_.argsort()[:, ::-1] 

for i in range(num_clusters):
    print("Cluster %d words:" % i, end='')
    
    temp_list = []
    for ind in order_centroids[i, :6]: #replace 6 with n words per cluster
        try:
            temp_list.append(terms[ind])
            print(' %s' % vocab_frame.ix[terms[ind].split(' ')].values.tolist()[0][0].encode('utf-8', 'ignore'), end=',')
        except:
            pass
    #the line below is for creating labels for the graph using the first threw words
    cluster_names[i] = ', '.join(temp_list[:3])
    
    print() #add whitespace
    print() #add whitespace
    
    print("Cluster %d titles:" % i, end='')
    try:
        for title in list(full_data.ix[i]['title'].values)[:30]:
            try:
                print(' %s,' % title, end='')
            except:
                pass
    except AttributeError:
        print(full_data.ix[i]['title'])
        
    print() #add whitespace
    print() #add whitespace
# Out:
# Top terms per cluster:
#
# Cluster 0 words: b'life', b'day', b'man', b'order', b'train', b'way',
#
# Cluster 0 titles: Trigun, Hachimitsu to Clover, Monster, Rurouni Kenshin: Meiji Kenkaku Romantan, Beck, Rozen Maiden, Azumanga Daioh, Black Cat, Shin Shirayuki-hime Densetsu Prétear, Aishiteruze Baby★★, El Hazard: The Alternative World, Gunslinger Girl, Blood+, Tokyo Underground, Vandread, Love Hina, Girls Bravo: First Season, Agatha Christie no Meitantei Poirot to Marple, Gad Guard, Noir, Akage no Anne, Argento Soma, Comic Party, Paradise Kiss, Mobile Police Patlabor, Midori no Hibi, Mama wa Shougaku 4 Nensei, Serial Experiments Lain, W: Wish, Shakugan no Shana,
#
# Cluster 1 words: b'family', b'father', b'house', b'daughter', b'mother', b'son',
#
# Cluster 1 titles: Rurouni Kenshin: Meiji Kenkaku Romantan - Ishinshishi e no Chinkonka, Ayashi no Ceres, Hana yori Dango, Fruits Basket, Fushigi Yuugi: Eikouden, Futakoi Alternative, Loveless, Onegai☆Twins, Sen to Chihiro no Kamikakushi, Jungle wa Itsumo Hare nochi Guu Deluxe, Hitsuji no Uta, Animal Yokochou, Abashiri Ikka, Kerokko Demetan, Akahori Gedou Hour Rabuge, Rose of Versailles, Wild Arms: Twilight Venom, Seikai no Senki, Tonari no Yamada-kun, Weiß Kreuz, Hotori: Tada Saiwai wo Koinegau, Armitage III: Dual-Matrix, Keroro Gunsou, Bishoujo Senshi Sailor Moon, Vampire Hunter D (2000), Honoo no Labyrinth, Ayakashi: Japanese Classic Horror, Hanbun no Tsuki ga Noboru Sora, Kage kara Mamoru!, Major S1,
#
# Cluster 2 words: b'space', b'earth', b'planet', b'powers', b'war', b'year',
#
# Cluster 9 titles: Sunabouzu, Futari Ecchi, Ghost in the Shell 2: Innocence, Dousou Kai, Keiraku no Houteishiki Level-C, Hit wo Nerae!, Injuu Gakuen La Blue Girl, Violence Jack: Harlem Bomber-hen, Makai Tenshi Djibril, Yarima Queen, Gun Frontier, Hi.Me.Go.To, Ai wa Kagi no Kazu dake... Fuuzoku Mansion, Maid in Heaven SuperS, Heisa Byouin, Malice@Doll, Saishuu Chikan Densha, Pigeon Blood, Kojin Taxi, Kisaku, Tokubetsu Jugyou 2, Ma ga Ochiru Yoru, Ane to Boin, Discipline, Lingeries, Choubatsu Yobikou, Hooligan, Ogenki Clinic, Dragon Knight, Onna Kyoushi Yumi no Houkago,
#
# Cluster 10 words: b'music', b'song', b'idol', b'band', b'program', b'night',
#
# Cluster 10 titles: Lemon Angel Project, Dragon Ball Z Movie 13: Ryuuken Bakuhatsu!! Goku ga Yaraneba Dare ga Yaru, On Your Mark, Cello Hiki no Gauche, Handsome Girl, Macross 7, Macross Flash Back 2012, Kiniro no Corda: Primo Passo, Green Green Specials, Nodame Cantabile, Shinkyoku Soukai Polyphonica, Amazing Nuts!, Yoshimune, Carol, Yuu☆Yuu☆Hakusho: Eizou Hakusho II, Genmu Senki Leda, Fujimi 2-choume Koukyougakudan, CLAMP in Wonderland, Shusaku, Prayers, Angelique: Twin Collection, Trapp Ikka Monogatari, Akai Koudan Zillion: Utahime Yakyoku, X²: Double X, Momotarou: Umi no Shinpei, Fuusen Shoujo Temple-chan, Final Fantasy VII: Advent Children Complete, Bronze: Kouji Nanjo Cathexis, Extra, Soratobu Toshi Keikaku,
#
# Cluster 11 words: b'student', b'schools', b'day', b'clubs', b'way', b'transferring',
#
# Cluster 11 titles: School Rumble, Aa! Megami-sama!, Tenshi Kinryouku, Ai Yori Aoshi, Chobits, DearS, Cluster Edge, Shuffle!, Bakuretsu Tenshi, Kono Minikuku mo Utsukushii Sekai, Juuni Kokuki, Ultra Maniac OVA, Tenkuu no Escaflowne, Initial D First Stage, Love Hina Again, Onegai☆Teacher, Shin Angel, Genshiken, Golden Boy, Bleach, Mahoromatic, Magical Canan, Bokusatsu Tenshi Dokuro-chan, Iriya no Sora, UFO no Natsu, Himiko-Den, Bible Black, Shiritsu Araiso Koutougakkou Seitokai Shikkoubu, Gokujou Seitokai, Okusama wa Joshikousei (TV), The Law of Ueki,
#
# Cluster 12 words: b'team', b'powers', b'battles', b'racing', b'attacked', b'strength',
#
# Cluster 12 titles: Eyeshield 21, Hungry Heart: Wild Striker, Initial D Fourth Stage, Prince of Tennis, Ghost in the Shell, Mobile Suit Gundam: The 08th MS Team, Mobile Suit Gundam: The 08th MS Team - Miller's Report, Akazukin Chacha, Ultra Maniac, Whistle!, Initial D Second Stage, Initial D Third Stage, Bakuten Shoot Beyblade, Dear Boys, Ace wo Nerae! (1979), Ace wo Nerae! 2, Burn Up Excess, eX-Driver the Movie, H2, Buzzer Beater, Spriggan, Dirty Pair, Bakuretsu Hunters, Pokemon, Hikaru no Go: Journey to the North Star Cup, Burn Up Scramble, Zoids Shin Seiki/Zero, Burn Up! W, Prince of Tennis: The Two Samurai, The First Game, Initial D Extra Stage,

# %% [markdown]
# ## Challenge 7
#
# Switch the init parameter to "random" (instead of the default kmeans++) and plot the inertia curve for each of the n_init values for K-Means: 1, 2, 3, 10 (n_init is the number of different runs to try with different random initializations).

# %%
class get_clusters(object):
    def __init__(self):
        #reset the data and clean the synopses
        self.reset_full_data()

        #get tf-idf matrix of terms
        self.tfidf_vectorizer = TfidfVectorizer(max_df=0.15, max_features=200000,
                                       min_df=0.01, stop_words=stops,
                                       use_idf=True, tokenizer=tokenize_and_stem, ngram_range=(1,3))

        self.tfidf_matrix = tfidf_vectorizer.fit_transform(cleaned_synops) #fit the vectorizer to synopses

        print("tfidf shape: ", tfidf_matrix.shape)
        self.terms = tfidf_vectorizer.get_feature_names()
        print("terms list:\n", terms)
    
    def reset_full_data(self):
        self.full_data = pd.read_csv('full_anime_data_set.csv')
        self.full_data.dropna(subset=['synopsis'], inplace=True)
        self.synops = list(self.full_data['synopsis'])

        short_indices = []
        for i, synop in enumerate(self.synops):
            if len(synop.split()) <= 25:
                short_indices.append(i)

        self.synops = [synop for i, synop in enumerate(self.synops) if i not in short_indices]
        self.full_data = self.full_data.drop(self.full_data.index[short_indices])
        
        self.cleaned_synops = clean_synops(self.synops, nouns_only=True)
    
    def get_top_terms_and_series(self, cluster_model):
        #declare and fit cluster model
        cluster_model = cluster_model
        cluster_model.fit(self.tfidf_matrix)
        clusters = cluster_model.labels_.tolist()

        #Set the index of data to cluster numbers
        data = self.full_data
        data['clusters'] = clusters
        data.set_index('clusters', inplace=True)
        
        #Prints out the top 6 cluster terms and series from cluster
        cluster_names = defaultdict(str)
        print("Top terms per cluster:")
        print()
        #sort cluster centers by proximity to centroid
        order_centroids = cluster_model.cluster_centers_.argsort()[:, ::-1] 

        for i in range(num_clusters):
            print("Cluster %d words:" % i, end='')

            temp_list = []
            for ind in order_centroids[i, :6]: #replace 6 with n words per cluster
                try:
                    temp_list.append(terms[ind])
                    print(' %s' % vocab_frame.ix[terms[ind].split(' ')].values.tolist()[0][0].encode('utf-8', 'ignore'), end=',')
                except:
                    pass
            #the line below is for creating labels for the graph using the first threw words
            cluster_names[i] = ', '.join(temp_list[:3])

            print() #add whitespace
            print() #add whitespace

            print("Cluster %d titles:" % i, end='')
            try:
                for title in list(full_data.ix[i]['title'].values)[:30]:
                    try:
                        print(' %s,' % title, end='')
                    except:
                        pass
            except AttributeError:
                print(full_data.ix[i]['title'])

            print('\n\n') #add whitespace

# %%
challenge_7 = get_clusters()
# Out:
# tfidf shape:  (6317, 278)
# terms list:
#  ['ability', 'academy', 'accident', 'act', 'action', 'adventure', 'age', 'alien', 'appear', 'appearance', 'arm', 'army', 'art', 'attack', 'attempt', 'band', 'battle', 'begin', 'blood', 'body', 'book', 'boy', 'break', 'brother', 'build', 'captain', 'capture', 'care', 'case', 'cat', 'cause', 'center', 'century', 'challenge', 'chance', 'change', 'chaos', 'child', 'childhood', 'childhood friend', 'city', 'clan', 'class', 'classmate', 'club', 'college', 'come', 'comedy', 'companion', 'company', 'computer', 'conflict', 'control', 'country', 'couple', 'course', 'create', 'creature', 'crew', 'crush', 'danger', 'dark', 'date', 'daughter', 'day', 'deal', 'death', 'decide', 'defeat', 'demon', 'desire', 'destruction', 'die', 'discover', 'doctor', 'dog', 'dr.', 'dragon', 'dream', 'earth', 'empire', 'encounter', 'enemy', 'energy', 'era', 'escape', 'evil', 'experience', 'eye', 'face', 'fact', 'fall', 'family', 'fate', 'father', 'fear', 'feel', 'fight', 'focus', 'force', 'forest', 'form', 'friend', 'friendship', 'future', 'galaxy', 'gang', 'ghost', 'girlfriend', 'goal', 'god', 'government', 'group', 'guy', 'hand', 'head', 'heart', 'hell', 'help', 'hero', 'hide', 'history', 'home', 'hop', 'hope', 'house', 'humanity', 'idol', 'incident', 'island', 'job', 'join', 'journey', 'justice', 'kid', 'kind', 'king', 'kingdom', 'land', 'lead', 'leader', 'learn', 'life', 'light', 'line', 'look', 'love', 'machine', 'magic', 'man', 'manage', 'mankind', 'master', 'matter', 'mean', 'member', 'memory', 'middle', 'mind', 'mission', 'money', 'monster', 'moon', 'mother', 'murder', 'music', 'mystery', 'nature', 'need', 'night', 'number', 'order', 'organization', 'owner', 'pair', 'parent', 'partner', 'party', 'pass', 'past', 'path', 'peace', 'person', 'picture', 'pilot', 'place', 'plan', 'planet', 'play', 'point', 'police', 'power', 'president', 'prince', 'princess', 'problem', 'professor', 'program', 'project', 'promise', 'purpose', 'quest', 'race', 'reality', 'reason', 'relationship', 'rescue', 'rest', 'result', 'return', 'revenge', 'robot', 'room', 'rule', 'run', 'school girl', 'school student', 'scientist', 'sea', 'search', 'secret', 'sex', 'shadow', 'share', 'ship', 'shop', 'sister', 'situation', 'sky', 'society', 'son', 'song', 'source', 'space', 'spirit', 'star', 'start', 'strength', 'struggle', 'student', 'study', 'style', 'suit', 'summer', 'surprise', 'sword', 'tale', 'task', 'teacher', 'team', 'technology', 'test', 'thing', 'threat', 'title', 'tokyo', 'town', 'train', 'transfer', 'travel', 'treasure', 'trip', 'trouble', 'truth', 'try', 'turn', 'universe', 'use', 'village', 'war', 'water', 'way', 'weapon', 'witch', 'woman', 'word', 'work', 'year']

# %%
for i in [1,2,3,10]:
    inertias = []
    cluster_range = list(range(1,8,1))
    for cluster_size in cluster_range:
        temp_list = []
        for _ in range(3):
            temp_km = KMeans(n_clusters=cluster_size, n_init=i)
            temp_km.fit(challenge_7.tfidf_matrix)
            temp_list.append(temp_km.inertia_)

        inertias.append(np.mean(temp_list))

    label= str(i) + ' inits'
    plt.plot(cluster_range, inertias, label=label)
    plt.legend(loc='best')
    plt.ylabel('total inertia distance')
    plt.xlabel('cluster size')

plt.show()

# %% [markdown]
# ## Challenge 8
#
# Download [this dataset on the purchase stats](https://archive.ics.uci.edu/ml/datasets/Wholesale+customers) from clients of a wholesale distributor. Cluster the clients based on their annual spending features (fresh, milk, grocery, frozen, detergents_paper, delicatessen). Remember to scale the features before clustering. After finding a reasonable amount of clusters, for EACH cluster, plot the histogram for every single feature: FRESH, MILK, GROCERY, FROZEN, DETERGENTS_PAPER, DELICATESSEN, CHANNEL, REGION. Is there a natural way to characterize each cluster? How would you describe each cluster to the wholesale distributor if you were working for them?

# %% [markdown]
# #### Note:
# Link was broken when I tried it so I skipped this.

# %% [markdown]
# ## Clustering Extensions (Optional)
#
# Use the same code for your previous clustering challenges.
#
# Repeat each challenge (except the inertia curves, since only the KMeans implementation gives a quick way of calculating that.) However, this time, try (both) Agglomerative Clustering and DBSCAN instead of KMeans.
#
# For text clustering, use cosine distance.
